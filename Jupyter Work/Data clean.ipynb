# %%
import alpha_vantage
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='1250F9WWA3Z77BIK')
# Get json object with the intraday data and another with  the call's metadata
data, meta_data = ts.get_intraday('TSLA')

# %%
data
# Out:
# {'2018-08-28 15:45:00': {'1. open': '312.5700',
#   '2. high': '313.1133',
#   '3. low': '311.8600',
#   '4. close': '311.8600',
#   '5. volume': '587473'},
#  '2018-08-28 15:30:00': {'1. open': '313.4463',
#   '2. high': '313.5500',
#   '3. low': '312.4003',
#   '4. close': '312.5011',
#   '5. volume': '263522'},
#  '2018-08-28 15:15:00': {'1. open': '313.5100',
#   '2. high': '313.6200',
#   '3. low': '313.2001',
#   '4. close': '313.4400',
#   '5. volume': '188594'},
#  '2018-08-28 15:00:00': {'1. open': '313.8101',
#   '2. high': '314.2176',
#   '3. low': '313.5500',
#   '4. close': '313.5850',
#   '5. volume': '137669'},
#  '2018-08-28 14:45:00': {'1. open': '314.1200',
#   '2. high': '314.6300',
#   '3. low': '313.3200',
#   '4. close': '313.8000',
#   '5. volume': '181212'},
#  '2018-08-28 14:30:00': {'1. open': '314.6838',
#   '2. high': '315.6554',
#   '3. low': '313.9900',
#   '4. close': '314.1200',
#   '5. volume': '185959'},
# ...

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='a539d7df2c7b43e1ac4d12f386d901e8')

# %%
x = [item['id'] for item in newsapi.get_sources()['sources']]

# %%
x
# Out:
# ['abc-news',
#  'abc-news-au',
#  'aftenposten',
#  'al-jazeera-english',
#  'ansa',
#  'argaam',
#  'ars-technica',
#  'ary-news',
#  'associated-press',
#  'australian-financial-review',
#  'axios',
#  'bbc-news',
#  'bbc-sport',
#  'bild',
#  'blasting-news-br',
#  'bleacher-report',
#  'bloomberg',
#  'breitbart-news',
#  'business-insider',
#  'business-insider-uk',
#  'buzzfeed',
#  'cbc-news',
#  'cbs-news',
#  'cnbc',
#  'cnn',
#  'cnn-es',
#  'crypto-coins-news',
#  'daily-mail',
#  'der-tagesspiegel',
#  'die-zeit',
#  'el-mundo',
#  'engadget',
#  'entertainment-weekly',
#  'espn',
#  'espn-cric-info',
#  'financial-post',
#  'financial-times',
#  'focus',
#  'football-italia',
#  'fortune',
#  'four-four-two',
#  'fox-news',
#  'fox-sports',
#  'globo',
#  'google-news',
#  'google-news-ar',
#  'google-news-au',
#  'google-news-br',
#  'google-news-ca',
#  'google-news-fr',
#  'google-news-in',
#  'google-news-is',
#  'google-news-it',
#  'google-news-ru',
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
newsapi.get_everything(q='zuckerberg',sort_by = 'publishedAt',language='en', sources='the-new-york-times')
# Out:
# {'status': 'ok',
#  'totalResults': 351,
#  'articles': [{'source': {'id': 'the-new-york-times',
#     'name': 'The New York Times'},
#    'author': 'Kate Conger',
#    'title': 'Dozens at Facebook Unite to Challenge Its ‘Intolerant’ Liberal Culture',
#    'description': 'In a rare sign of internal dissent, more than 100 employees have formed a group to agitate for better representation of conservative views.',
#    'url': 'https://www.nytimes.com/2018/08/28/technology/inside-facebook-employees-political-bias.html',
#    'urlToImage': 'https://static01.nyt.com/images/2018/08/29/business/29facebook1/29facebook1-facebookJumbo.jpg',
#    'publishedAt': '2018-08-28T23:37:33Z'},
#   {'source': {'id': 'the-new-york-times', 'name': 'The New York Times'},
#    'author': 'ALEX WILLIAMS',
#    'title': 'Maybe Your Sleep Problem Isn’t a Problem',
# ...

# %%
from langdetect import detect

# %%
detect('Twitterがさらに多くの“組織的な情報操作に関わった”アカウントを停止')
# Out:
# 'ja'

# %%
html_page = requests.get('https://www.nytimes.com/2018/08/28/technology/inside-facebook-employees-political-bias.html')

# %%
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
text
# Out:
# [<p>Advertisement</p>,
#  <p>Supported by</p>,
#  <p class="css-1cbhw1y e1x1pwtg1" itemprop="author creator" itemscope="" itemtype="http://schema.org/Person">By<!-- --> <a class="css-1s28epf e1x1pwtg0" href="https://www.nytimes.com/by/kate-conger"><span class="css-1baulvz" itemprop="name">Kate Conger</span></a> and <a class="css-1s28epf e1x1pwtg0" href="https://www.nytimes.com/by/sheera-frenkel"><span class="css-1baulvz" itemprop="name">Sheera Frenkel</span></a></p>,
#  <p class="css-1i0edl6 e2kc3sl0">SAN FRANCISCO — The post went up quietly on Facebook’s internal message board last week. Titled “We Have a Problem With Political Diversity,” it quickly took off inside the social network.</p>,
# ...

# %%
import nltk.classify.util
nltk.download('stopwords')
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
text= soup.find_all('p')
new_text = []
for item in text:
    clean = re.findall(r'\w+', item.text)
    x = item.text
    for i in clean:
        if i in stopwords.words('english'):
            pass
        else:
            new_text.append(i.lower())

# %%
def count_vectorize(article, vocab=None):
    if vocab:
        unique_words = vocab
    else:
        unique_words = list(set(article))  
    article_dict = {i:0 for i in unique_words}   
    for word in article:
        article_dict[word] += 1    
    return article_dict

test_vectorized = count_vectorize(new_text, vocab=None)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sid = SentimentIntensityAnalyzer()

# %%
scores = sid.polarity_scores(x)

# %%
x
# Out:
# 'But at the same time let’s not pretend that tech is in any way Public Enemy No. 1, or that we represent all that is wrong with the world, or that tech people are uniquely and specially terrible, or that we should be the primary focus of criticism re how the world works, just because we are particularly striking and visible. If you want to deal with the enemies of a better world in order of importance, then I’m afraid you’re going to need to start elsewhere.'

# %%
scores
# Out:
# {'neg': 0.176, 'neu': 0.745, 'pos': 0.078, 'compound': -0.9002}

# %%
from google.cloud import language
language_client = language.Client()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-319-abd4d3207ec5> in <module>()
#       1 from google.cloud import language
# ----> 2 language_client = language.Client()
#
# AttributeError: module 'google.cloud.language' has no attribute 'Client'

# %%
from textblob import TextBlob

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
blob = TextBlob(x, classifier = cl)
blob.tags

blob.noun_phrases
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-330-b2824d29471e> in <module>()
# ----> 1 blob = TextBlob(x, classifier = cl)
#       2 blob.tags
#       3
#       4 blob.noun_phrases
#
# NameError: name 'cl' is not defined

# %%
blob.sentences
# Out:
# [Sentence("But at the same time let’s not pretend that tech is in any way Public Enemy No."),
#  Sentence("1, or that we represent all that is wrong with the world, or that tech people are uniquely and specially terrible, or that we should be the primary focus of criticism re how the world works, just because we are particularly striking and visible."),
#  Sentence("If you want to deal with the enemies of a better world in order of importance, then I’m afraid you’re going to need to start elsewhere.")]

# %%
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# Out:
# 0.0
# -0.045
# -0.04999999999999999

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyser = SentimentIntensityAnalyzer()

# %%
import tweepy

auth = tweepy.OAuthHandler('UGxquWoEO6bisCK6FGhBlrKYp', 'dRw1GVeyzgdfYQD1S4aEZRGaGCep9QusVZWI9gt4uHriOZG4WI')
auth.set_access_token('333368932-TP9Vp0cWTZ8FywrhtYj3kSvDjhcSPuISON7ROh4f', 'k42e1QG5t72HiDzi4M7WxRfTUvUodZLKFT6268Eb6mLzw')

api = tweepy.API(auth)

public_tweets = api.home_timeline()
# for tweet in public_tweets:
#     print(tweet.text)

# %%
def daily_tweets(search_name, since_date, until_date,value):
    clean_tweet = []
    plug = value
    for i in range(75):
        all_tweets = api.search(q='@'+search_name,lang = 'en', count = 100, since = since_date, until = until_date,max_id = plug)
        for tweet in all_tweets:
            plug = str(tweet.id - 1)
            if 'RT' not in tweet.text:
                if '#NowPlaying' not in tweet.text:
                    empty = {}
                    empty['t_id'] = tweet.id
                    empty['text'] = tweet.text
                    empty['time_stamp'] = tweet.created_at
                    clean_tweet.append(empty)
    return clean_tweet

# %%
x = daily_tweets('facebook', '2018-08-29', None,None)

# %%
u = daily_tweets('snapchat', '2018-08-30',None,None)

# %%
m = daily_tweets('snapchat', '2018-08-29', '2018-08-30',None)

# %%
n = daily_tweets('snapchat', '2018-08-28', '2018-08-29',None)

# %%
q = daily_tweets('snapchat', '2018-08-27', '2018-08-28',None)

# %%
s = daily_tweets('snapchat', '2018-08-27', '2018-08-28',None)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-957-3994bec5dd8d> in <module>()
# ----> 1 s = daily_tweets('snapchat', '2018-08-27', '2018-08-28',None)
#
# <ipython-input-668-7124d5dc4bee> in daily_tweets(search_name, since_date, until_date, value)
#       3     plug = value
#       4     for i in range(75):
# ----> 5         all_tweets = api.search(q='@'+search_name,lang = 'en', count = 100, since = since_date, until = until_date,max_id = plug)
#       6         for tweet in all_tweets:
#       7             plug = str(tweet.id - 1)
#
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     230
# ...

# %%
df_today = pd.DataFrame(u)
dftues = pd.DataFrame(n)
dfwed = pd.DataFrame(m)
dfmon = pd.DataFrame(q)
dfsun = pd.DataFrame(s)

# %%
# dftues[(dftues.time_stamp < '2018-08-28 12:00:00')] #189

# %%
# df_today #284

# %%
# dfwed[(dfwed.time_stamp < '2018-08-29 12:00:00')] #200

# %%
# dfmon[(dfmon.time_stamp < '2018-08-27 12:00:00')] #146

# %%
import pandas as pd

# %%
u = daily_tweets('sonos', '2018-08-30',None,None)

# %%
m = daily_tweets('sonos', '2018-08-29', '2018-08-30',None)

# %%
n = daily_tweets('sonos', '2018-08-28', '2018-08-29',None)

# %%
i = daily_tweets('sonos', '2018-08-27', '2018-08-28',None)

# %%
q = daily_tweets('sonos', '2018-08-23', '2018-08-24',None)

# %%
v = daily_tweets('sonos', '2018-08-26', '2018-08-27',None)

# %%
k = daily_tweets('sonos', '2018-08-24', '2018-08-26',None)

# %%
z = daily_tweets('sonos', '2018-08-25', '2018-08-26',None)

# %%
# e = daily_tweets('sonos', '2018-08-22', '2018-08-23',None)

# %%
df_today = pd.DataFrame(u)
dftues = pd.DataFrame(n)
dfwed = pd.DataFrame(m)
dfthurs = pd.DataFrame(q)
dfmon = pd.DataFrame(i)
dfsun = pd.DataFrame(v)
dfsat = pd.DataFrame(z)
dffri = pd.DataFrame(k)
# dfpwed = pd.DataFrame(e)

# %%
sonos_tweets = pd.DataFrame()
sonos_tweets = sonos_tweets.append(dftues, ignore_index=True)
sonos_tweets = sonos_tweets.append(dfwed, ignore_index=True)
sonos_tweets = sonos_tweets.append(dfthurs, ignore_index=True)
sonos_tweets = sonos_tweets.append(dfmon, ignore_index=True)
sonos_tweets = sonos_tweets.append(dfsun, ignore_index=True)
sonos_tweets = sonos_tweets.append(dfsat, ignore_index=True)
sonos_tweets = sonos_tweets.append(dffri, ignore_index=True)
# sonos_tweets = sonos_tweets.append(dfpwed, ignore_index=True)

# %%
add_polarity(sonos_tweets)

# %%
sonos_tweets.to_csv('sonos_tweets.csv')

# %%
# set(sonos_tweets.time_stamp)

# %%
# sonos_tweets

# %%
# dftues[(dftues.time_stamp < '2018-08-28 12:00:00')] #189

# %%
# df_today #284

# %%
# dfwed[(dfwed.time_stamp < '2018-08-29 12:00:00')] #200

# %%
# dfmon[(dfmon.time_stamp < '2018-08-27 12:00:00')] #146

# %%
y = daily_tweets('facebook', '2018-08-28', '2018-08-29',None)
df = df.append(y)

# %%
y = daily_tweets('facebook', '2018-08-27', '2018-08-28',None)
df = df.append(y)

# %%
y = daily_tweets('facebook', '2018-08-26', '2018-08-27',None)
df = df.append(y)

# %%
y = daily_tweets('facebook', '2018-08-25', '2018-08-26',None)
df = df.append(y)

# %%
y = daily_tweets('facebook', '2018-08-24', '2018-08-25',None)
df = df.append(y)

# %%
y = daily_tweets('facebook', '2018-08-23', '2018-08-24',None)
df = df.append(y)

# %%
y = daily_tweets('facebook', '2018-08-22', '2018-08-23',None)
df = df.append(y)

# %%
y = daily_tweets('facebook', '2018-08-20', '2018-08-21',None)
df = df.append(y)

# %%
y = daily_tweets('facebook', '2018-08-19', '2018-08-20',None)
df = df.append(y)

# %%
df.to_csv('tweets_8_28.csv',index=False)

# %%
d2 = pd.read_csv('tweets_8_28.csv')

# %%
def add_polarity(dataframe):
    polarities = []
    neg_pos = []
    for item in list(dataframe.text):
        sentiment = analyser.polarity_scores(item)
        polarities.append(sentiment['compound'])
        if sentiment['compound'] > 0:
            neg_pos.append('pos')
        elif sentiment['compound'] < 0:
            neg_pos.append('neg')
        elif sentiment['compound'] == 0:
            neg_pos.append('neutral')
    dataframe['vader_sentiment'] = polarities
    dataframe['sentiment'] = neg_pos

# %%
add_polarity(d2)

# %%
d2 = d2[(ts.index > '2018-08-25')]

# %%
import warnings
warnings.filterwarnings('ignore')

# Load required libraries
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
ts = d2.set_index('time_stamp')
ts.index = pd.to_datetime(ts.index)
ts =ts.drop(['text','t_id','sentiment'],axis=1)

# %%
ts.plot()

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

rolmean = ts.rolling(window=12).mean()
rolstd = ts.rolling(window=12).std()
orig = plt.plot(ts, color='blue',label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Facebook Sentiment Analysis 8/20-8/28')
plt.show(block=False)

# %%
import alpha_vantage
from alpha_vantage.timeseries import TimeSeries
stock = TimeSeries(key='1250F9WWA3Z77BIK')
# Get json object with the intraday data and another with  the call's met/adata
data, meta_data = stock.get_intraday(symbol ='FB', interval='1min')

# %%
today_prices = pd.DataFrame(data)

# %%
today_prices_df = pd.DataFrame(today_prices.T)

# %%
today_prices_df.to_csv('1MININT_8.28_stock.csv')

# %%
fb = pd.DataFrame(data)
stock_df = pd.DataFrame(fb.T)
tsfb =stock.drop(['1. open','2. high','3. low','5. volume'],axis=1)
tsfb.index = pd.to_datetime(tsfb.index)

# %%
# stock.to_csv('stock.csv')

# %%
tsfb['4. close'] = tsfb['4. close'].astype(float)

# %%
type(tsfb['4. close'])
# Out:
# pandas.core.series.Series

# %%
rolmeanfb = tsfb.rolling(window=12).mean()
# rolstdfb = tsfb.rolling(window=12).std()
orig = plt.plot(tsfb, color='blue',label='Original')
mean = plt.plot(rolmeanfb, color='red', label='Rolling Mean')
# std = plt.plot(rolstdfb, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Facebook Stock Price 8/20-8/28')
plt.show(block=False)

# %%
import pandas as pd

# %%
sonos_stock = pd.DataFrame()

# %%
data_five, meta = stock.get_intraday(symbol ='AAPL', interval='5min')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-03c218960475> in <module>()
# ----> 1 data_five, meta = stock.get_intraday(symbol ='AAPL', interval='5min')
#
# NameError: name 'stock' is not defined

# %%
sonos_five_thurs = pd.DataFrame(data_five)
sonos_five_thurs = pd.DataFrame(sonos_five_thurs.T)
sonos_five_thurs.index = pd.to_datetime(sonos_five_thurs.index)
sonos_five_thurs['interval'] = 5
sonos_stock = sonos_stock.append(sonos_five_thurs)

# %%
data_15, meta_15 = stock.get_intraday(symbol ='SONO', interval='15min')
sonos_fifteen = pd.DataFrame(data_15)
sonos_fifteen = pd.DataFrame(sonos_fifteen.T)
sonos_fifteen.index = pd.to_datetime(sonos_fifteen.index)
sonos_fifteen['interval'] = 15
sonos_stock = sonos_stock.append(sonos_fifteen)

# %%
data_30, meta_30 = stock.get_intraday(symbol ='SONO', interval='30min')
sonos_thirty = pd.DataFrame(data_30)
sonos_thirty = pd.DataFrame(sonos_thirty.T)
sonos_thirty.index = pd.to_datetime(sonos_thirty.index)
sonos_thirty['interval'] = 30
sonos_stock = sonos_stock.append(sonos_thirty)

# %%
sonos_stock.to_csv('apple_stock_8_30.csv')

# %%
weds_df = pd.DataFrame(weds_minute_data)
weds_df = pd.DataFrame(weds_df.T)

# %%
from alpha_vantage.techindicators import TechIndicators
import matplotlib.pyplot as plt

ti = TechIndicators(key='1250F9WWA3Z77BIK', output_format='pandas')
macd, meta_data = ti.get_macd(symbol='FB', interval='30min', series_type='close')
tech_indicators = pd.DataFrame()
tech_indicators = tech_indicators.append(macd)
tech_indicators = tech_indicators[(tech_indicators.index > '2018-08-20')]

# %%
stoch, meta_data = ti.get_stoch(symbol='FB', interval='30min')
stoch =  stoch[(stoch.index > '2018-08-20')]
tech_indicators = tech_indicators.join(stoch)

# %%
rsi, meta_data = ti.get_rsi(symbol='FB', interval='30min',time_period=4, series_type='close')
rsi =  rsi[(rsi.index > '2018-08-20')]
tech_indicators = tech_indicators.join(rsi)

# %%
adx, meta_data = ti.get_adx(symbol='FB', interval='30min',time_period=4)
adx =  adx[(adx.index > '2018-08-20')]
tech_indicators = tech_indicators.join(adx)

# %%
cci, meta_data = ti.get_cci(symbol='FB', interval='30min',time_period=4)
cci =  cci[(cci.index > '2018-08-20')]
tech_indicators = tech_indicators.join(cci)

# %%
aroon, meta_data = ti.get_aroon(symbol='FB', interval='30min',time_period=4)
aroon =  aroon[(aroon.index > '2018-08-20')]
tech_indicators = tech_indicators.join(aroon)

# %%
bbands, meta_data = ti.get_bbands(symbol='FB', interval='30min',time_period=4, series_type='close')
bbands =  bbands[(bbands.index > '2018-08-20')]
tech_indicators = tech_indicators.join(bbands)

# %%
ad, meta_data = ti.get_ad(symbol='FB', interval='30min')
ad =  ad[(ad.index > '2018-08-20')]
tech_indicators = tech_indicators.join(ad)

# %%
obv, meta_data = ti.get_obv(symbol='FB', interval='30min')
obv =  obv[(obv.index > '2018-08-20')]
tech_indicators = tech_indicators.join(obv)

# %%
tech_indicators.to_csv('fb_tech_indicators.csv')

# %%
tech_indicators
# Out:
#                     MACD  MACD_Signal  MACD_Hist    SlowK    SlowD      RSI  \
# date
# 2018-08-20 09:30 -1.1398      -1.2665     0.1268  51.1156  73.2709  21.2825
# 2018-08-20 10:00 -1.1830      -1.2498     0.0668  32.9281  54.5476  22.5937
# 2018-08-20 10:30 -1.2183      -1.2435     0.0252  20.2348  34.7595  20.4740
# 2018-08-20 11:00 -1.1861      -1.2320     0.0460  29.6701  27.6110  42.6500
# 2018-08-20 11:30 -1.1553      -1.2167     0.0614  32.8121  27.5723  40.0659
# 2018-08-20 12:00 -1.0761      -1.1886     0.1125  58.7079  40.3967  57.9166
# 2018-08-20 12:30 -0.9966      -1.1502     0.1535  73.1819  54.9006  59.8859
# 2018-08-20 13:00 -0.9239      -1.1049     0.1811  87.1673  73.0190  59.2868
# 2018-08-20 13:30 -0.8379      -1.0515     0.2136  84.5296  81.6263  68.4991
# 2018-08-20 14:00 -0.7624      -0.9937     0.2313  77.5098  83.0689  67.0253
# 2018-08-20 14:30 -0.7362      -0.9422     0.2060  54.1426  72.0607  35.3990
# ...

# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

sp = SectorPerformances(key='1250F9WWA3Z77BIK', output_format='pandas')
data, meta_data = sp.get_sector()

# %%
tech_indicators
# Out:
#                   MACD_Signal  MACD_Hist    MACD    SlowK    SlowD      RSI  \
# date
# 2018-08-20 09:30       0.2626     0.0664  0.3289  69.6082  61.0456  89.3834
# 2018-08-20 10:00       0.2837     0.0845  0.3682  79.1741  70.9573  91.9591
# 2018-08-20 10:30       0.3090     0.1013  0.4103  81.4526  76.7450  94.0457
# 2018-08-20 11:00       0.3335     0.0978  0.4313  88.5739  83.0669  80.8482
# 2018-08-20 11:30       0.3539     0.0816  0.4354  84.8411  84.9559  68.0934
# 2018-08-20 12:00       0.3697     0.0633  0.4329  71.7276  81.7142  66.4987
# 2018-08-20 12:30       0.3832     0.0540  0.4371  64.3909  73.6532  76.3268
# 2018-08-20 13:00       0.3930     0.0393  0.4323  58.0679  64.7288  68.6343
# 2018-08-20 13:30       0.3991     0.0244  0.4235  59.8766  60.7785  68.6343
# 2018-08-20 14:00       0.4044     0.0211  0.4254  71.7504  63.2317  82.1934
# 2018-08-20 14:30       0.4089     0.0180  0.4268  86.0373  72.5548  85.2035
# ...

# %%
tweets_wed = ts[((ts.index > '2018-08-29 8:00:00') & (ts.index< '2018-08-29 18:00:00'))]

# %%
tweets_wed.head()
# Out:
#                      vader_sentiment
# time_stamp
# 2018-08-29 20:03:44           0.0000
# 2018-08-29 20:03:28           0.4019
# 2018-08-29 20:03:22           0.0000
# 2018-08-29 20:03:10          -0.6468
# 2018-08-29 20:03:00           0.7096

# %%
# weds_df =weds_df.drop(['1. open','2. high','3. low','5. volume'],axis=1)
weds_df.index = pd.to_datetime(weds_df.index)
weds_df['4. close'] = weds_df['4. close'].astype(float)
weds_df = weds_df[(weds_df.index>'2018-08-29')]

# %%
rolmean_wedstock = weds_df.rolling(window=12).mean()
# rolstdfb = tsfb.rolling(window=12).std()
orig = plt.plot(weds_df, color='blue',label='Original')
mean = plt.plot(rolmean_wedstock, color='red', label='Rolling Mean')
# std = plt.plot(rolstdfb, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Facebook Stock Price 8/28')
plt.show(block=False)

# %%
rolmean_tweetwed = tweets_wed.rolling(window=12).mean()
rolstd_tweetwed = tweets_wed.rolling(window=12).std()
orig = plt.plot(tweets_wed, color='blue',label='Original')
mean = plt.plot(rolmean_tweetwed, color='red', label='Rolling Mean')
std = plt.plot(rolstd_tweetwed, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Facebook Sentiment Analysis 8/28')
plt.show(block=False)

# %%
hourly = tweets_wed
# hourly.index = hourly.index.time
hourly.boxplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-826-27e1b0009310> in <module>()
#       1 hourly = tweets_wed
# ----> 2 hourly.index = hourly.index.time
#       3 hourly.boxplot()
#
# AttributeError: 'Index' object has no attribute 'time'

# %%
year_matrix = tweets_wed.T
plt.matshow( year_matrix, interpolation=None, aspect='auto', cmap=plt.cm.Spectral_r)
plt.show()

# %%
tesla_tweets = api.search(q='@facebook',lang = 'en', count = 100, since = '2018-08-20', until = '2018-08-29',result_type='recent', max_id = str(1034586592319623173-1))
for tweet in tesla_tweets:
    if 'RT' not in tweet.text:
        print(tweet.created_at)
# Out:
# 2018-08-28 23:39:57
# 2018-08-28 23:39:35
# 2018-08-28 23:38:31
# 2018-08-28 23:38:27
# 2018-08-28 23:38:06
# 2018-08-28 23:37:43
# 2018-08-28 23:37:26
# 2018-08-28 23:36:43
# 2018-08-28 23:36:36
# 2018-08-28 23:36:01
# 2018-08-28 23:35:58
# 2018-08-28 23:35:21
# 2018-08-28 23:35:04
# 2018-08-28 23:32:42
# 2018-08-28 23:32:37
# 2018-08-28 23:32:36
# 2018-08-28 23:31:38
# 2018-08-28 23:31:33
# 2018-08-28 23:30:57
# 2018-08-28 23:30:41
# 2018-08-28 23:30:32
# 2018-08-28 23:30:08
# 2018-08-28 23:28:56
# 2018-08-28 23:27:13
# 2018-08-28 23:26:52
# 2018-08-28 23:26:48
# 2018-08-28 23:26:10

# %%
tesla_tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x10fb00e48>, _json={'created_at': 'Tue Aug 28 23:40:31 +0000 2018', 'id': 1034586556370169857, 'id_str': '1034586556370169857', 'text': 'RT @Greystone: #HCIC18 We’re excited to have members of @MayoClinicSMN present "Making Your Social Media Metrics Actionable" - case studies…', 'truncated': False, 'entities': {'hashtags': [{'text': 'HCIC18', 'indices': [15, 22]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Greystone', 'name': 'Greystone', 'id': 15393854, 'id_str': '15393854', 'indices': [3, 13]}, {'screen_name': 'MayoClinicSMN', 'name': 'Mayo Clinic SMN', 'id': 2477085852, 'id_str': '2477085852', 'indices': [56, 70]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_
# ...

# %%
from searchtweets import ResultStream, gen_rule_payload, load_credentials
from searchtweets import collect_results

# %%
search_args = load_credentials(account_type="premium",
            env_overwrite=False)
earch_args.keys()
#     dict_keys(['bearer_token', 'endpoint'])
# Out:
# cannot read file ~/.twitter_keys.yaml
# Error parsing YAML file; searching for valid environment variables
# Your credentials are not configured correctly and  you are missing a required field. Please see the  readme for proper configuration
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/searchtweets/credentials.py in _parse_credentials(search_creds, account_type)
#      93             search_args = {
# ---> 94                 "bearer_token": search_creds["bearer_token"],
#      95                 "endpoint": search_creds["endpoint"]}
#
# KeyError: 'bearer_token'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-398-923a4439f61c> in <module>()
#       1 search_args = load_credentials(account_type="premium",
# ...

# %%
import yaml

# %%
premium_search_args = load_credentials("/.twitter_keys.yaml",'premium',
                                       yaml_key="search_tweets_api",
                                       env_overwrite=False)
# Out:
# cannot read file /.twitter_keys.yaml
# Error parsing YAML file; searching for valid environment variables
# Your credentials are not configured correctly and  you are missing a required field. Please see the  readme for proper configuration
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/searchtweets/credentials.py in _parse_credentials(search_creds, account_type)
#      93             search_args = {
# ---> 94                 "bearer_token": search_creds["bearer_token"],
#      95                 "endpoint": search_creds["endpoint"]}
#
# KeyError: 'bearer_token'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-420-6debf7c7d225> in <module>()
# ...

# %%
rule = gen_rule_payload("beyonce", results_per_call=100)

# %%
rule
# Out:
# '{"query": "beyonce", "maxResults": 100}'

# %%
tweets = collect_results(rule,
                         max_results=100,
                         result_stream_args=premium_search_args)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-364-2a009856de01> in <module>()
#       1 tweets = collect_results(rule,
#       2                          max_results=100,
# ----> 3                          result_stream_args=enterprise_search_args)
#
# NameError: name 'enterprise_search_args' is not defined

# %%
[print(tweet.all_text, end='\n\n') for tweet in tweets[0:10]];

# %%
import base64

# %%
data = '{"query":"(facebook OR zuckerberg OR (#facebook) OR (@facebook) is:verified", "fromDate": "201807230000", "toDate": "201807250000}'

# %%
import requests
import json

endpoint = "https://api.twitter.com/1.1/tweets/search/fullarchive/dev.json" 

headers = {"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAKJz8QAAAAAAzYW%2Febm14JXdHbNEoWUUZN%2F%2BhBI%3DxQqif9o4dvy2ljhWaeH0QXnLAwNgAZuroVIVkR0rKX5SqhQLno", "Content-Type": "application/json"}  

data = '{"query":"(facebook) lang:eng", "fromDate": "201807230000", "toDate": "201808250000"}'

response = requests.post(endpoint,data=data,headers=headers).json()

print(json.dumps(response, indent = 2))
# Out:
# {
#   "results": [
#     {
#       "created_at": "Fri Aug 24 03:35:25 +0000 2018",
#       "id": 1032833731239833600,
#       "id_str": "1032833731239833600",
#       "text": "Would They Know https://t.co/H32FFz9aoB",
#       "source": "<a href=\"http://www.facebook.com/twitter\" rel=\"nofollow\">Facebook</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 17858855,
#         "id_str": "17858855",
#         "name": "JaryWelker",
#         "screen_name": "JaryWelker",
#         "location": "Phoenix, AZ",
#         "url": "http://jlwelker.wordpress.com/",
#         "description": "Family man with beautiful wife and great children. My passion is to inspire others to bloom where they are planted and find peace in the moment. I am a Mormon.",
# ...

# %%
len(response['results'])
# Out:
# 100

# %%
from __future__ import print_function

import base64
import requests
import urllib.parse

OAUTH2_TOKEN = 'https://api.twitter.com/oauth2/token'


def get_bearer_token(consumer_key, consumer_secret):
    # enconde consumer key
    consumer_key = urllib.parse.quote(consumer_key)
    # encode consumer secret
    consumer_secret = urllib.parse.quote(consumer_secret)
    # create bearer token
    bearer_token = consumer_key + ':' + consumer_secret
    # base64 encode the token
    base64_encoded_bearer_token = base64.b64encode(bearer_token.encode('utf-8'))
    # set headers
    headers = {
        "Authorization": "Basic " + base64_encoded_bearer_token.decode('utf-8') + "",
        "Content-Type": "application/x-www-form-urlencoded;charset=UTF-8",
        "Content-Length": "29"}

    response = requests.post(OAUTH2_TOKEN, headers=headers, data={'grant_type': 'client_credentials'})
    to_json = response.json()
    print(to_json)
#     print("token_type = %s\naccess_token  = %s" % (to_json['token_type'], to_json['access_token']))


def main():
    consumer_key = input('Enter your consumer key: ')
    consumer_secret = input('Enter your consumer secret: ')
    print("***** ***** ***** *****")
    get_bearer_token(consumer_key, consumer_secret)


if __name__ == "__main__":
    main()
# Out:
# Enter your consumer key: UGxquWoEO6bisCK6FGhBlrKYp
# Enter your consumer secret: dRw1GVeyzgdfYQD1S4aEZRGaGCep9QusVZWI9gt4uHriOZG4WI
# ***** ***** ***** *****
# {'token_type': 'bearer', 'access_token': 'AAAAAAAAAAAAAAAAAAAAAKJz8QAAAAAAzYW%2Febm14JXdHbNEoWUUZN%2F%2BhBI%3DxQqif9o4dvy2ljhWaeH0QXnLAwNgAZuroVIVkR0rKX5SqhQLno'}

# %%
main()
# Out:
# Enter your consumer key: UGxquWoEO6bisCK6FGhBlrKYp
# Enter your consumer secret: dRw1GVeyzgdfYQD1S4aEZRGaGCep9QusVZWI9gt4uHriOZG4WI
# ***** ***** ***** *****
