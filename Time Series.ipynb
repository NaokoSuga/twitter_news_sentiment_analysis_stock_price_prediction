# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series
import numpy as np

import matplotlib.pylab as plt
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
fb_df = pd.read_csv('fb_tweets_stock.csv', index_col = 0)
# fb_df.index = pd.to_datetime(close_price.index)
# close_price = fb_df['4. close']

# %%
close_price.plot()
# # plt.xlim(set(close_price.index.day))
# plt.xlabel('day')
# plt.ylabel('price($)') 
# plt.title('Stock Price - Facebook')
# plt.legend() 
# plt.show()
