# %%
import pandas as pd
import datetime

# %%
import pandas as pd

# %%
from datetime import datetime, timedelta

# %%
import numpy as np

# %%
art_df = pd.read_csv('fb_articles_20180822_20180829_df.csv')

# %%
art_df = art_df.drop('Unnamed: 0', axis =1)

# %%
art_df.index = art_df.publishedAt
art_df.index = pd.to_datetime(art_df.index)
art_df = art_df.drop('publishedAt',axis=1)

# %%
art_df['day'] = art_df.index.date

# %%
new = pd.DataFrame(index=art_df.index.round('30min'))
new['day'] = new.index.date

# %%
art_df.source = art_df.source.fillna('Other')

# %%
new.head(1)
# Out:
#                             day
# publishedAt
# 2018-08-29 10:30:00  2018-08-29

# %%
values = []
for index, row in new.iterrows():
    avg = art_df[(art_df.index <= index)].groupby('day', as_index=False)['compound'].mean()
    avg.day = pd.to_datetime(avg.day)
    value = avg.loc[avg['day'] == str(row.day)]['compound'].values
    if len(value) > 0:
        values.append(value[0])
    else:
        values.append(np.mean(avg['compound'].values))

new['day compound avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
values = []
for index, row in new.iterrows():
    avg = art_df[(art_df.index <= index)].groupby('day', as_index=False)['pos'].mean()
    avg.day = pd.to_datetime(avg.day)
    value = avg.loc[avg['day'] == str(row.day)]['pos'].values
    if len(value) > 0:
        values.append(value[0])
    else:
        values.append(np.mean(avg['pos'].values))

new['day positive avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
values = []
for index, row in new.iterrows():
    avg = art_df[(art_df.index <= index)].groupby('day', as_index=False)['neg'].mean()
    avg.day = pd.to_datetime(avg.day)
    value = avg.loc[avg['day'] == str(row.day)]['neg'].values
    if len(value) > 0:
        values.append(value[0])
    else:
        values.append(np.mean(avg['neg'].values))

new['day negative avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
values = []
for index, row in new.iterrows():
    avg = art_df[(art_df.index <= index)].groupby('day', as_index=False)['neu'].mean()
    avg.day = pd.to_datetime(avg.day)
    value = avg.loc[avg['day'] == str(row.day)]['neu'].values
    if len(value) > 0:
        values.append(value[0])
    else:
        values.append(np.mean(avg['neu'].values))

new['day neutral avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
values = []
for index, row in new.iterrows():
    holder = []
    avg = pd.DataFrame(art_df[(art_df.index <= index)]['neu'])
    avg.index = pd.to_datetime(avg.index)
    avg['day'] = avg.index.date
    avg.day = pd.to_datetime(avg.day)
    day_of = avg[(avg['day'] == str(row.day))]['neu'].values
    day_before = avg.loc[avg.day == str((row.day - timedelta(days=1)))]['neu'].values
    holder.extend(day_of)
    holder.extend(day_before)
    if len(holder) > 0:
        values.append(np.mean(holder))
    else:
        values.append(np.mean(avg['neu'].values))

new['two day neutral avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
values = []
for index, row in new.iterrows():
    holder = []
    avg = pd.DataFrame(art_df[(art_df.index <= index)]['pos'])
    avg.index = pd.to_datetime(avg.index)
    avg['day'] = avg.index.date
    avg.day = pd.to_datetime(avg.day)
    day_of = avg[(avg['day'] == str(row.day))]['pos'].values
    day_before = avg.loc[avg.day == str((row.day - timedelta(days=1)))]['pos'].values
    holder.extend(day_of)
    holder.extend(day_before)
    if len(holder) > 0:
        values.append(np.mean(holder))
    else:
        values.append(np.mean(avg['pos'].values))

new['two day positive avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
values = []
for index, row in new.iterrows():
    holder = []
    avg = pd.DataFrame(art_df[(art_df.index <= index)]['neg'])
    avg.index = pd.to_datetime(avg.index)
    avg['day'] = avg.index.date
    avg.day = pd.to_datetime(avg.day)
    day_of = avg[(avg['day'] == str(row.day))]['neg'].values
    day_before = avg.loc[avg.day == str((row.day - timedelta(days=1)))]['neg'].values
    holder.extend(day_of)
    holder.extend(day_before)
    if len(holder) > 0:
        values.append(np.mean(holder))
    else:
        values.append(np.mean(avg['neg'].values))

new['two day negative avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
values = []
for index, row in new.iterrows():
    holder = []
    avg = pd.DataFrame(art_df[(art_df.index <= index)]['compound'])
    avg.index = pd.to_datetime(avg.index)
    avg['day'] = avg.index.date
    avg.day = pd.to_datetime(avg.day)
    day_of = avg[(avg['day'] == str(row.day))]['compound'].values
    day_before = avg.loc[avg.day == str((row.day - timedelta(days=1)))]['compound'].values
    holder.extend(day_of)
    holder.extend(day_before)
    if len(holder) > 0:
        values.append(np.mean(holder))
    else:
        values.append(np.mean(avg['compound'].values))

new['two day compound avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
for source in list(set(art_df.source)):
    print(source)
    values = []
    for index, row in new.iterrows():
        holder = []
        avg = pd.DataFrame(art_df[(art_df.index <= index) & (art_df.source == source)]['compound'])
        avg.index = pd.to_datetime(avg.index)
        avg['day'] = avg.index.date
        avg.day = pd.to_datetime(avg.day)
        day_of = avg[(avg['day'] == str(row.day))]['compound'].values
        day_before = avg.loc[avg.day == str((row.day - timedelta(days=1)))]['compound'].values
        holder.extend(day_of)
        holder.extend(day_before)
        if len(holder) > 0:
            values.append(np.mean(holder))
        else:
            values.append(np.mean(avg['compound'].values))

    new['two day ' + str(source) +' compound avg'] = values
# Out:
# nbc-news
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# business-insider
# the-new-york-times
# abc-news
# reuters
# wired
# techcrunch

# %%
for source in list(set(art_df.source)):
    print(source)
    values = []
    for index, row in new.iterrows():
        holder = []
        avg = pd.DataFrame(art_df[(art_df.index <= index) & (art_df.source == source)]['neg'])
        avg.index = pd.to_datetime(avg.index)
        avg['day'] = avg.index.date
        avg.day = pd.to_datetime(avg.day)
        day_of = avg[(avg['day'] == str(row.day))]['neg'].values
        day_before = avg.loc[avg.day == str((row.day - timedelta(days=1)))]['neg'].values
        holder.extend(day_of)
        holder.extend(day_before)
        if len(holder) > 0:
            values.append(np.mean(holder))
        else:
            values.append(np.mean(avg['neg'].values))

    new['two day ' + str(source) +' neg avg'] = values
# Out:
# nbc-news
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# business-insider
# the-new-york-times
# abc-news
# reuters
# wired
# techcrunch

# %%
for source in list(set(art_df.source)):
    print(source)
    values = []
    for index, row in new.iterrows():
        holder = []
        avg = pd.DataFrame(art_df[(art_df.index <= index) & (art_df.source == source)]['pos'])
        avg.index = pd.to_datetime(avg.index)
        avg['day'] = avg.index.date
        avg.day = pd.to_datetime(avg.day)
        day_of = avg[(avg['day'] == str(row.day))]['pos'].values
        day_before = avg.loc[avg.day == str((row.day - timedelta(days=1)))]['pos'].values
        holder.extend(day_of)
        holder.extend(day_before)
        if len(holder) > 0:
            values.append(np.mean(holder))
        else:
            values.append(np.mean(avg['pos'].values))

    new['two day ' + str(source) +' pos avg'] = values
# Out:
# nbc-news
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# business-insider
# the-new-york-times
# abc-news
# reuters
# wired
# techcrunch

# %%
for source in list(set(art_df.source)):
    print(source)
    values = []
    for index, row in new.iterrows():
        holder = []
        avg = pd.DataFrame(art_df[(art_df.index <= index) & (art_df.source == source)]['neu'])
        avg.index = pd.to_datetime(avg.index)
        avg['day'] = avg.index.date
        avg.day = pd.to_datetime(avg.day)
        day_of = avg[(avg['day'] == str(row.day))]['neu'].values
        day_before = avg.loc[avg.day == str((row.day - timedelta(days=1)))]['neu'].values
        holder.extend(day_of)
        holder.extend(day_before)
        if len(holder) > 0:
            values.append(np.mean(holder))
        else:
            values.append(np.mean(avg['neu'].values))

    new['two day ' + str(source) +' neu avg'] = values
# Out:
# nbc-news
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# business-insider
# the-new-york-times
# abc-news
# reuters
# wired
# techcrunch

# %%
for source in list(set(art_df.source)):   
    values = []
    for index, row in new.iterrows():
        avg = art_df[(art_df.index <= index)& (art_df.source == source)].groupby('day', as_index=False)['compound'].mean()
        avg.day = pd.to_datetime(avg.day)
        value = avg.loc[avg['day'] == str(row.day)]['compound'].values
        if len(value) > 0:
            values.append(value[0])
        else:
            values.append(np.mean(avg['compound'].values))

    new['one day ' + str(source) +' compound avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
for source in list(set(art_df.source)):   
    values = []
    for index, row in new.iterrows():
        avg = art_df[(art_df.index <= index)& (art_df.source == source)].groupby('day', as_index=False)['neg'].mean()
        avg.day = pd.to_datetime(avg.day)
        value = avg.loc[avg['day'] == str(row.day)]['neg'].values
        if len(value) > 0:
            values.append(value[0])
        else:
            values.append(np.mean(avg['neg'].values))

    new['one day ' + str(source) +' neg avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
for source in list(set(art_df.source)):   
    values = []
    for index, row in new.iterrows():
        avg = art_df[(art_df.index <= index)& (art_df.source == source)].groupby('day', as_index=False)['pos'].mean()
        avg.day = pd.to_datetime(avg.day)
        value = avg.loc[avg['day'] == str(row.day)]['pos'].values
        if len(value) > 0:
            values.append(value[0])
        else:
            values.append(np.mean(avg['pos'].values))

    new['one day ' + str(source) +' pos avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
for source in list(set(art_df.source)):   
    values = []
    for index, row in new.iterrows():
        avg = art_df[(art_df.index <= index)& (art_df.source == source)].groupby('day', as_index=False)['neu'].mean()
        avg.day = pd.to_datetime(avg.day)
        value = avg.loc[avg['day'] == str(row.day)]['neu'].values
        if len(value) > 0:
            values.append(value[0])
        else:
            values.append(np.mean(avg['neu'].values))

    new['one day ' + str(source) +' neu avg'] = values
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
new.to_csv('fb_article_avgs.csv')

# %%
new
# Out:
#                             day  day compound avg  day positive avg  \
# publishedAt
# 2018-08-29 10:30:00  2018-08-29         -0.326379          0.061857
# 2018-08-29 01:30:00  2018-08-29         -0.123067          0.071833
# 2018-08-28 11:00:00  2018-08-28         -0.458514          0.072571
# 2018-08-28 02:30:00  2018-08-28         -0.974540          0.049800
# 2018-08-28 02:30:00  2018-08-28         -0.974540          0.049800
# 2018-08-27 11:30:00  2018-08-27         -0.961660          0.061800
